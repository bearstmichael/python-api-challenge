# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 569

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------1")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Build query URL
    url = "https://api.openweathermap.org/data/2.5/weather?"
    
    place = f"q={city}&"
    apik = f"appid={weather_api_key}&"
    unit = f"units=imperial"

    city_url = url+place+apik+unit

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------2")
print("Data Retrieval Complete      ")
print("-----------------------------3")
# Out:
# Beginning Data Retrieval
# -----------------------------1
# Processing Record 1 of Set 1 | hawaiian paradise park
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | egilsstadir
# Processing Record 6 of Set 1 | invercargill
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | hamilton
# Processing Record 9 of Set 1 | barki saria
# Processing Record 10 of Set 1 | menongue
# Processing Record 11 of Set 1 | vila franca do campo
# Processing Record 12 of Set 1 | grytviken
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | edinburgh of the seven seas
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | san cristobal
# Processing Record 18 of Set 1 | tanrake village
# City not found. Skipping...
# Processing Record 19 of Set 1 | ardakan
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | bubaque
# Processing Record 22 of Set 1 | blackmans bay
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | la passe
# Processing Record 25 of Set 1 | chulakkurgan
# Processing Record 26 of Set 1 | iskateley
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | longboat key
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | jutai
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | atafu village
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | stanley
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | ust-nera
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | high river
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | saint-joseph
# Processing Record 41 of Set 1 | karratha
# Processing Record 42 of Set 1 | lukolela
# Processing Record 43 of Set 1 | chepo
# Processing Record 44 of Set 1 | haiku-pauwela
# Processing Record 45 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 46 of Set 1 | la'ie
# Processing Record 47 of Set 1 | touros
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | kuraymah
# Processing Record 50 of Set 1 | dara
# Processing Record 0 of Set 2 | debre birhan
# Processing Record 1 of Set 2 | praia da vitoria
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | nar'yan-mar
# Processing Record 4 of Set 2 | portland
# Processing Record 5 of Set 2 | enewetak
# Processing Record 6 of Set 2 | garachico
# Processing Record 7 of Set 2 | sydney
# Processing Record 8 of Set 2 | mineral wells
# Processing Record 9 of Set 2 | klyuchi
# Processing Record 10 of Set 2 | kaga bandoro
# Processing Record 11 of Set 2 | sao felix do xingu
# Processing Record 12 of Set 2 | constantia
# Processing Record 13 of Set 2 | port mathurin
# Processing Record 14 of Set 2 | uturoa
# Processing Record 15 of Set 2 | aydarken
# Processing Record 16 of Set 2 | nagqu
# Processing Record 17 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 2 | sitka
# Processing Record 19 of Set 2 | san juan nepomuceno
# Processing Record 20 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 2 | isafjordur
# Processing Record 22 of Set 2 | nova sintra
# Processing Record 23 of Set 2 | tocopilla
# Processing Record 24 of Set 2 | usogorsk
# Processing Record 25 of Set 2 | dalandzadgad
# Processing Record 26 of Set 2 | margaret river
# Processing Record 27 of Set 2 | khorixas
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | changqing
# Processing Record 31 of Set 2 | ixtapa
# Processing Record 32 of Set 2 | hobyo
# Processing Record 33 of Set 2 | brokopondo
# Processing Record 34 of Set 2 | college
# Processing Record 35 of Set 2 | brisas de zicatela
# Processing Record 36 of Set 2 | badger
# Processing Record 37 of Set 2 | papao
# Processing Record 38 of Set 2 | porto novo
# Processing Record 39 of Set 2 | minas de marcona
# Processing Record 40 of Set 2 | vilyuysk
# Processing Record 41 of Set 2 | viedma
# Processing Record 42 of Set 2 | oranjemund
# Processing Record 43 of Set 2 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 44 of Set 2 | imbituba
# Processing Record 45 of Set 2 | bilibino
# Processing Record 46 of Set 2 | priargunsk
# Processing Record 47 of Set 2 | saldanha
# Processing Record 48 of Set 2 | mount pearl
# Processing Record 49 of Set 2 | la libertad
# Processing Record 0 of Set 3 | rio grande
# Processing Record 1 of Set 3 | itaituba
# Processing Record 2 of Set 3 | ribadesella
# Processing Record 3 of Set 3 | ushuaia
# Processing Record 4 of Set 3 | keflavik
# Processing Record 5 of Set 3 | tangjiazhuang
# Processing Record 6 of Set 3 | callao
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | sao joao da barra
# Processing Record 9 of Set 3 | olonkinbyen
# Processing Record 10 of Set 3 | ulanhot
# Processing Record 11 of Set 3 | toliara
# Processing Record 12 of Set 3 | pandan
# Processing Record 13 of Set 3 | meiganga
# Processing Record 14 of Set 3 | ulladulla
# Processing Record 15 of Set 3 | sanctuary point
# Processing Record 16 of Set 3 | kharp
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | nushki
# Processing Record 19 of Set 3 | khandyga
# Processing Record 20 of Set 3 | saipan
# Processing Record 21 of Set 3 | ponta delgada
# Processing Record 22 of Set 3 | susuman
# Processing Record 23 of Set 3 | basco
# Processing Record 24 of Set 3 | nago
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | san sebastian de la gomera
# Processing Record 27 of Set 3 | pechora
# Processing Record 28 of Set 3 | san julian
# Processing Record 29 of Set 3 | salekhard
# Processing Record 30 of Set 3 | fale old settlement
# Processing Record 31 of Set 3 | kimbe
# Processing Record 32 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 33 of Set 3 | l'isle-jourdain
# Processing Record 34 of Set 3 | iqaluit
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | kismayo
# Processing Record 37 of Set 3 | port alfred
# Processing Record 38 of Set 3 | georgievka
# Processing Record 39 of Set 3 | lijiang
# Processing Record 40 of Set 3 | dudinka
# Processing Record 41 of Set 3 | badr hunayn
# Processing Record 42 of Set 3 | la sarre
# Processing Record 43 of Set 3 | kavieng
# Processing Record 44 of Set 3 | punta arenas
# Processing Record 45 of Set 3 | yuzhno-kurilsk
# Processing Record 46 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 3 | kapuskasing
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | lerwick
# Processing Record 0 of Set 4 | pinarhisar
# Processing Record 1 of Set 4 | machico
# Processing Record 2 of Set 4 | whitehorse
# Processing Record 3 of Set 4 | lehigh acres
# Processing Record 4 of Set 4 | khunti
# Processing Record 5 of Set 4 | columbus
# Processing Record 6 of Set 4 | altay
# Processing Record 7 of Set 4 | zheleznodorozhnyy
# Processing Record 8 of Set 4 | kuanda
# Processing Record 9 of Set 4 | dryden
# Processing Record 10 of Set 4 | butterworth
# Processing Record 11 of Set 4 | hadibu
# Processing Record 12 of Set 4 | kununurra
# Processing Record 13 of Set 4 | mebane
# Processing Record 14 of Set 4 | borogontsy
# Processing Record 15 of Set 4 | villa bruzual
# Processing Record 16 of Set 4 | malango
# Processing Record 17 of Set 4 | tofol
# Processing Record 18 of Set 4 | lorengau
# Processing Record 19 of Set 4 | as sulaymaniyah
# Processing Record 20 of Set 4 | hyrum
# Processing Record 21 of Set 4 | wailua homesteads
# Processing Record 22 of Set 4 | tadmur
# Processing Record 23 of Set 4 | horta
# Processing Record 24 of Set 4 | madera
# Processing Record 25 of Set 4 | kananga
# Processing Record 26 of Set 4 | igarka
# Processing Record 27 of Set 4 | pama
# Processing Record 28 of Set 4 | rongelap
# Processing Record 29 of Set 4 | birjand
# Processing Record 30 of Set 4 | banda aceh
# Processing Record 31 of Set 4 | pariaman
# Processing Record 32 of Set 4 | severnoye
# Processing Record 33 of Set 4 | siddapur
# Processing Record 34 of Set 4 | utrik
# Processing Record 35 of Set 4 | frontera
# Processing Record 36 of Set 4 | vanimo
# Processing Record 37 of Set 4 | huron
# Processing Record 38 of Set 4 | aasiaat
# Processing Record 39 of Set 4 | broken hill
# Processing Record 40 of Set 4 | talcahuano
# Processing Record 41 of Set 4 | cabedelo
# Processing Record 42 of Set 4 | shenjiamen
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | alofi
# Processing Record 45 of Set 4 | vadso
# Processing Record 46 of Set 4 | fort mcmurray
# Processing Record 47 of Set 4 | ancud
# Processing Record 48 of Set 4 | fort bragg
# Processing Record 49 of Set 4 | manokwari
# Processing Record 0 of Set 5 | nuku'alofa
# Processing Record 1 of Set 5 | sylvan lake
# Processing Record 2 of Set 5 | likhoslavl'
# Processing Record 3 of Set 5 | dunafoldvar
# Processing Record 4 of Set 5 | as sulayyil
# Processing Record 5 of Set 5 | sao lourenco do sul
# Processing Record 6 of Set 5 | tiksi
# Processing Record 7 of Set 5 | palmer
# Processing Record 8 of Set 5 | kasempa
# Processing Record 9 of Set 5 | sandnessjoen
# Processing Record 10 of Set 5 | dapa
# Processing Record 11 of Set 5 | portmore
# Processing Record 12 of Set 5 | lycksele
# Processing Record 13 of Set 5 | nemuro
# Processing Record 14 of Set 5 | qamdo
# Processing Record 15 of Set 5 | tiptur
# Processing Record 16 of Set 5 | sisimiut
# Processing Record 17 of Set 5 | suva
# Processing Record 18 of Set 5 | esbjerg
# Processing Record 19 of Set 5 | chonchi
# Processing Record 20 of Set 5 | west island
# Processing Record 21 of Set 5 | polyarnyy
# Processing Record 22 of Set 5 | siasi
# Processing Record 23 of Set 5 | coquimbo
# Processing Record 24 of Set 5 | takoradi
# Processing Record 25 of Set 5 | collipulli
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | plymstock
# Processing Record 28 of Set 5 | chake chake
# Processing Record 29 of Set 5 | sant lluis
# Processing Record 30 of Set 5 | boyolangu
# Processing Record 31 of Set 5 | tommot
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | santana
# Processing Record 34 of Set 5 | lashio
# Processing Record 35 of Set 5 | kuta
# Processing Record 36 of Set 5 | capelinha
# Processing Record 37 of Set 5 | novyy urgal
# Processing Record 38 of Set 5 | korla
# Processing Record 39 of Set 5 | anderson
# Processing Record 40 of Set 5 | turar ryskulov
# Processing Record 41 of Set 5 | iganga
# Processing Record 42 of Set 5 | tucuma
# Processing Record 43 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 44 of Set 5 | udachny
# Processing Record 45 of Set 5 | sovetsk
# Processing Record 46 of Set 5 | akureyri
# Processing Record 47 of Set 5 | novodvinsk
# Processing Record 48 of Set 5 | yunfu
# Processing Record 49 of Set 5 | shimoda
# Processing Record 0 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 6 | greymouth
# Processing Record 2 of Set 6 | newport
# Processing Record 3 of Set 6 | essaouira
# Processing Record 4 of Set 6 | moires
# Processing Record 5 of Set 6 | viqueque
# Processing Record 6 of Set 6 | alice springs
# Processing Record 7 of Set 6 | moab
# Processing Record 8 of Set 6 | broome
# Processing Record 9 of Set 6 | puerto deseado
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | tondano
# Processing Record 12 of Set 6 | vorgashor
# Processing Record 13 of Set 6 | angaur state
# Processing Record 14 of Set 6 | makawao
# Processing Record 15 of Set 6 | sao vicente
# Processing Record 16 of Set 6 | worland
# Processing Record 17 of Set 6 | neyriz
# Processing Record 18 of Set 6 | bairnsdale
# Processing Record 19 of Set 6 | kiffa
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | ayaviri
# Processing Record 22 of Set 6 | arteche
# Processing Record 23 of Set 6 | gadzhiyevo
# Processing Record 24 of Set 6 | namibe
# Processing Record 25 of Set 6 | howrah
# Processing Record 26 of Set 6 | byron bay
# Processing Record 27 of Set 6 | yamoussoukro
# Processing Record 28 of Set 6 | papatowai
# Processing Record 29 of Set 6 | tazovsky
# Processing Record 30 of Set 6 | daira din panah
# Processing Record 31 of Set 6 | praya
# Processing Record 32 of Set 6 | tarawa
# Processing Record 33 of Set 6 | lompoc
# Processing Record 34 of Set 6 | bargaal
# Processing Record 35 of Set 6 | jombang
# Processing Record 36 of Set 6 | kingston
# Processing Record 37 of Set 6 | sinabang
# Processing Record 38 of Set 6 | turuntayevo
# Processing Record 39 of Set 6 | inhambane
# Processing Record 40 of Set 6 | ubinskoye
# Processing Record 41 of Set 6 | hithadhoo
# Processing Record 42 of Set 6 | vorkuta
# Processing Record 43 of Set 6 | al faw
# Processing Record 44 of Set 6 | prineville
# Processing Record 45 of Set 6 | tolanaro
# Processing Record 46 of Set 6 | puerto el triunfo
# Processing Record 47 of Set 6 | puerto lopez
# Processing Record 48 of Set 6 | flying fish cove
# Processing Record 49 of Set 6 | limulunga
# Processing Record 0 of Set 7 | phan rang-thap cham
# Processing Record 1 of Set 7 | falenki
# Processing Record 2 of Set 7 | teuva
# Processing Record 3 of Set 7 | arraial do cabo
# Processing Record 4 of Set 7 | robertsport
# Processing Record 5 of Set 7 | asadabad
# Processing Record 6 of Set 7 | wuhai
# Processing Record 7 of Set 7 | kone
# Processing Record 8 of Set 7 | san fernando
# Processing Record 9 of Set 7 | schweizer-reneke
# Processing Record 10 of Set 7 | kurduvadi
# Processing Record 11 of Set 7 | alcains
# Processing Record 12 of Set 7 | port-gentil
# Processing Record 13 of Set 7 | afaahiti
# Processing Record 14 of Set 7 | pontevedra
# Processing Record 15 of Set 7 | crane
# Processing Record 16 of Set 7 | prien
# Processing Record 17 of Set 7 | lospalos
# Processing Record 18 of Set 7 | tibanbang
# Processing Record 19 of Set 7 | palikir - national government center
# Processing Record 20 of Set 7 | hovd
# Processing Record 21 of Set 7 | port elizabeth
# Processing Record 22 of Set 7 | sa'dah
# Processing Record 23 of Set 7 | lae
# Processing Record 24 of Set 7 | yanji
# Processing Record 25 of Set 7 | tamanrasset
# Processing Record 26 of Set 7 | morris
# Processing Record 27 of Set 7 | pisco
# Processing Record 28 of Set 7 | puerto baquerizo moreno
# Processing Record 29 of Set 7 | weno
# Processing Record 30 of Set 7 | stephenville
# Processing Record 31 of Set 7 | labrador city
# Processing Record 32 of Set 7 | mount gambier
# Processing Record 33 of Set 7 | varena
# Processing Record 34 of Set 7 | aykhal
# Processing Record 35 of Set 7 | taguatinga
# Processing Record 36 of Set 7 | fuglafjordur
# Processing Record 37 of Set 7 | tachilek
# City not found. Skipping...
# Processing Record 38 of Set 7 | luoyang
# Processing Record 39 of Set 7 | belmonte
# Processing Record 40 of Set 7 | remire-montjoly
# Processing Record 41 of Set 7 | yanchep
# Processing Record 42 of Set 7 | san jose de lourdes
# City not found. Skipping...
# Processing Record 43 of Set 7 | bela
# Processing Record 44 of Set 7 | saskatoon
# Processing Record 45 of Set 7 | laojunmiao
# Processing Record 46 of Set 7 | happy valley-goose bay
# Processing Record 47 of Set 7 | xining
# Processing Record 48 of Set 7 | corner brook
# Processing Record 49 of Set 7 | christchurch
# Processing Record 0 of Set 8 | korsakov
# Processing Record 1 of Set 8 | mersing
# Processing Record 2 of Set 8 | ferkessedougou
# Processing Record 3 of Set 8 | lazaro cardenas
# Processing Record 4 of Set 8 | sault ste. marie
# Processing Record 5 of Set 8 | sittwe
# Processing Record 6 of Set 8 | keningau
# Processing Record 7 of Set 8 | tbeng meanchey
# Processing Record 8 of Set 8 | tual
# Processing Record 9 of Set 8 | fortuna
# Processing Record 10 of Set 8 | cajamarca
# Processing Record 11 of Set 8 | brejo da madre de deus
# Processing Record 12 of Set 8 | paradip garh
# Processing Record 13 of Set 8 | zheshart
# Processing Record 14 of Set 8 | sydney mines
# Processing Record 15 of Set 8 | biograd na moru
# Processing Record 16 of Set 8 | kerikeri
# Processing Record 17 of Set 8 | grand falls-windsor
# Processing Record 18 of Set 8 | kitakata
# Processing Record 19 of Set 8 | magadan
# Processing Record 20 of Set 8 | revda
# Processing Record 21 of Set 8 | atar
# Processing Record 22 of Set 8 | al jawf
# Processing Record 23 of Set 8 | yeniseysk
# Processing Record 24 of Set 8 | balkanabat
# Processing Record 25 of Set 8 | east london
# Processing Record 26 of Set 8 | codrington
# Processing Record 27 of Set 8 | camiri
# Processing Record 28 of Set 8 | sola
# Processing Record 29 of Set 8 | dhidhdhoo
# Processing Record 30 of Set 8 | tuba city
# Processing Record 31 of Set 8 | lamarque
# Processing Record 32 of Set 8 | mglin
# Processing Record 33 of Set 8 | bekalta
# Processing Record 34 of Set 8 | dickinson
# Processing Record 35 of Set 8 | berdigestyakh
# Processing Record 36 of Set 8 | newman
# Processing Record 37 of Set 8 | benguela
# Processing Record 38 of Set 8 | thunder bay
# Processing Record 39 of Set 8 | oak ridge
# Processing Record 40 of Set 8 | selfoss
# Processing Record 41 of Set 8 | bamboo flat
# Processing Record 42 of Set 8 | puerto quijarro
# Processing Record 43 of Set 8 | kiunga
# Processing Record 44 of Set 8 | sinop
# Processing Record 45 of Set 8 | notodden
# Processing Record 46 of Set 8 | coxen hole
# Processing Record 47 of Set 8 | mouila
# Processing Record 48 of Set 8 | cockburn town
# Processing Record 49 of Set 8 | karbinci
# Processing Record 0 of Set 9 | thomasville
# Processing Record 1 of Set 9 | kigoma
# Processing Record 2 of Set 9 | upington
# Processing Record 3 of Set 9 | fort-shevchenko
# Processing Record 4 of Set 9 | san antonio de pale
# Processing Record 5 of Set 9 | qianzhou
# Processing Record 6 of Set 9 | i-n-salah
# Processing Record 7 of Set 9 | al ghayzah
# Processing Record 8 of Set 9 | hilo
# Processing Record 9 of Set 9 | macgregor
# Processing Record 10 of Set 9 | prudnik
# Processing Record 11 of Set 9 | simrishamn
# Processing Record 12 of Set 9 | coari
# Processing Record 13 of Set 9 | kayangel
# Processing Record 14 of Set 9 | eyl
# Processing Record 15 of Set 9 | kapa'a
# Processing Record 16 of Set 9 | saksaul'skiy
# City not found. Skipping...
# Processing Record 17 of Set 9 | rabo de peixe
# Processing Record 18 of Set 9 | mao
# Processing Record 19 of Set 9 | roma
# Processing Record 20 of Set 9 | puerto madryn
# Processing Record 21 of Set 9 | urdinarrain
# Processing Record 22 of Set 9 | barabai
# Processing Record 23 of Set 9 | dour
# Processing Record 24 of Set 9 | kudahuvadhoo
# Processing Record 25 of Set 9 | kaka
# Processing Record 26 of Set 9 | fernie
# Processing Record 27 of Set 9 | gaalkacyo
# Processing Record 28 of Set 9 | markala
# Processing Record 29 of Set 9 | lisakovsk
# Processing Record 30 of Set 9 | nantucket
# Processing Record 31 of Set 9 | malvan
# Processing Record 32 of Set 9 | lata
# Processing Record 33 of Set 9 | tsiombe
# Processing Record 34 of Set 9 | luganville
# Processing Record 35 of Set 9 | margate
# Processing Record 36 of Set 9 | prince rupert
# Processing Record 37 of Set 9 | mermoz boabab
# Processing Record 38 of Set 9 | ipora
# Processing Record 39 of Set 9 | barcelos
# Processing Record 40 of Set 9 | n'diareme limamoulaye
# City not found. Skipping...
# Processing Record 41 of Set 9 | copala
# Processing Record 42 of Set 9 | lihue
# Processing Record 43 of Set 9 | dien bien phu
# Processing Record 44 of Set 9 | norwalk
# Processing Record 45 of Set 9 | petauke
# Processing Record 46 of Set 9 | shenkursk
# Processing Record 47 of Set 9 | labytnangi
# Processing Record 48 of Set 9 | klaksvik
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 0 of Set 10 | colonia
# Processing Record 1 of Set 10 | aral
# Processing Record 2 of Set 10 | baie-comeau
# Processing Record 3 of Set 10 | bazar-e yakawlang
# City not found. Skipping...
# Processing Record 4 of Set 10 | ambovombe
# Processing Record 5 of Set 10 | suzun
# Processing Record 6 of Set 10 | moose jaw
# Processing Record 7 of Set 10 | banff
# Processing Record 8 of Set 10 | maturin
# Processing Record 9 of Set 10 | aioun
# Processing Record 10 of Set 10 | melendugno
# Processing Record 11 of Set 10 | choyr
# Processing Record 12 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 13 of Set 10 | yaren
# Processing Record 14 of Set 10 | mora
# Processing Record 15 of Set 10 | al mutayrifi
# Processing Record 16 of Set 10 | mangrol
# Processing Record 17 of Set 10 | chauk
# Processing Record 18 of Set 10 | vilhena
# Processing Record 19 of Set 10 | nusaybin
# Processing Record 20 of Set 10 | salalah
# Processing Record 21 of Set 10 | ma'rib
# Processing Record 22 of Set 10 | luderitz
# Processing Record 23 of Set 10 | la leonesa
# Processing Record 24 of Set 10 | harper
# Processing Record 25 of Set 10 | ebon
# Processing Record 26 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 27 of Set 10 | batouri
# Processing Record 28 of Set 10 | shingu
# Processing Record 29 of Set 10 | northam
# Processing Record 30 of Set 10 | belyy yar
# Processing Record 31 of Set 10 | kavaratti
# Processing Record 32 of Set 10 | zhongshu
# Processing Record 33 of Set 10 | flen
# Processing Record 34 of Set 10 | el calafate
# Processing Record 35 of Set 10 | port townsend
# Processing Record 36 of Set 10 | cooper's town
# Processing Record 37 of Set 10 | suoyarvi
# Processing Record 38 of Set 10 | fada
# Processing Record 39 of Set 10 | ta`u
# Processing Record 40 of Set 10 | prince albert
# Processing Record 41 of Set 10 | joshimath
# Processing Record 42 of Set 10 | tazacorte
# Processing Record 43 of Set 10 | parsabad
# Processing Record 44 of Set 10 | berezovyy
# Processing Record 45 of Set 10 | manaure
# Processing Record 46 of Set 10 | constitucion
# Processing Record 47 of Set 10 | nasice
# Processing Record 48 of Set 10 | at taj
# Processing Record 49 of Set 10 | st. john's
# Processing Record 0 of Set 11 | saudarkrokur
# Processing Record 1 of Set 11 | milledgeville
# Processing Record 2 of Set 11 | ad dabbah
# Processing Record 3 of Set 11 | cidreira
# Processing Record 4 of Set 11 | sitia
# Processing Record 5 of Set 11 | walvis bay
# Processing Record 6 of Set 11 | sao jose da coroa grande
# Processing Record 7 of Set 11 | mandalgovi
# Processing Record 8 of Set 11 | ijuw
# City not found. Skipping...
# Processing Record 9 of Set 11 | timimoun
# Processing Record 10 of Set 11 | taltal
# Processing Record 11 of Set 11 | vila velha
# Processing Record 12 of Set 11 | naranjal
# Processing Record 13 of Set 11 | nabire
# Processing Record 14 of Set 11 | goz beida
# Processing Record 15 of Set 11 | yanbu
# Processing Record 16 of Set 11 | westerland
# Processing Record 17 of Set 11 | ballina
# Processing Record 18 of Set 11 | peniche
# Processing Record 19 of Set 11 | demyansk
# Processing Record 20 of Set 11 | altai
# Processing Record 21 of Set 11 | calingasta
# Processing Record 22 of Set 11 | ba
# City not found. Skipping...
# Processing Record 23 of Set 11 | iaciara
# Processing Record 24 of Set 11 | brigantine
# Processing Record 25 of Set 11 | plyeshchanitsy
# Processing Record 26 of Set 11 | mar del plata
# Processing Record 27 of Set 11 | corralillo
# Processing Record 28 of Set 11 | nogliki
# Processing Record 29 of Set 11 | cheremushki
# Processing Record 30 of Set 11 | adrar
# Processing Record 31 of Set 11 | valka
# Processing Record 32 of Set 11 | bardai
# Processing Record 33 of Set 11 | karasuk
# Processing Record 34 of Set 11 | grand island
# Processing Record 35 of Set 11 | prince george
# Processing Record 36 of Set 11 | chipinge
# Processing Record 37 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 38 of Set 11 | el limon
# Processing Record 39 of Set 11 | lakhipur
# Processing Record 40 of Set 11 | puerto carreno
# Processing Record 41 of Set 11 | quellon
# Processing Record 42 of Set 11 | aljezur
# Processing Record 43 of Set 11 | labuan
# Processing Record 44 of Set 11 | coyhaique
# Processing Record 45 of Set 11 | piti village
# Processing Record 46 of Set 11 | kolonia town
# Processing Record 47 of Set 11 | bikenibeu village
# Processing Record 48 of Set 11 | nikolayevsk-on-amure
# Processing Record 49 of Set 11 | juneau
# Processing Record 0 of Set 12 | nuuk
# Processing Record 1 of Set 12 | ukiah
# Processing Record 2 of Set 12 | obolensk
# Processing Record 3 of Set 12 | veraval
# Processing Record 4 of Set 12 | farsan
# Processing Record 5 of Set 12 | don sak
# Processing Record 6 of Set 12 | poronaysk
# Processing Record 7 of Set 12 | tafuna
# Processing Record 8 of Set 12 | altamont
# Processing Record 9 of Set 12 | darwin
# Processing Record 10 of Set 12 | jumla
# Processing Record 11 of Set 12 | okhotsk
# Processing Record 12 of Set 12 | uyuni
# Processing Record 13 of Set 12 | general conesa
# Processing Record 14 of Set 12 | dar kulayb
# Processing Record 15 of Set 12 | jangipur
# Processing Record 16 of Set 12 | kadugli
# Processing Record 17 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 18 of Set 12 | san patricio
# -----------------------------2
# Data Retrieval Complete
# -----------------------------3

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          550
# Lat           550
# Lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  hawaiian paradise park  19.5933 -154.9731     76.51        79         100
# 1            port lincoln -34.7333  135.8667     57.24        58         100
# 2            puerto ayora  -0.7393  -90.3518     78.55        89          21
# 3                waitangi -43.9535 -176.5597     60.82        83          94
# 4             egilsstadir  65.2653  -14.3948     39.11        70           0
#
#    Wind Speed Country        Date
# 0        8.05      US  1684288169
# 1        7.58      AU  1684288169
# 2        4.00      EC  1684288170
# 3        5.99      NZ  1684288170
# 4        5.75      IS  1684288170

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        hawaiian paradise park  19.5933 -154.9731     76.51        79
# 1                  port lincoln -34.7333  135.8667     57.24        58
# 2                  puerto ayora  -0.7393  -90.3518     78.55        89
# 3                      waitangi -43.9535 -176.5597     60.82        83
# 4                   egilsstadir  65.2653  -14.3948     39.11        70
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        8.05      US  1684288169
# 1               100        7.58      AU  1684288169
# 2                21        4.00      EC  1684288170
# 3                94        5.99      NZ  1684288170
# 4                 0        5.75      IS  1684288170

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Graph features
plt.title('City Latitude vs. Temperature (2023-05-16)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()

# Plot graph
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'])

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Graph features
plt.title('City Latitude vs. Humidity (2023-05-16)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Plot graph
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'])

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Graph features
plt.title('City Latitude vs. Cloudiness (2023-05-16)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Plot graph
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'])

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Graph features
plt.title('City Latitude vs. Wind Speed (2023-05-16)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Plot graph
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'])

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define Function
def f(df,x_values,y_values,xpos,ypos):
    x = df[x_values]
    y = df[y_values]
    
    plt.scatter(x,y)
    
    (m, b, r, p, s) = linregress(x, y)
    regress_values = x * m + b
    line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))

    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(xpos,ypos),fontsize=15,color="red")
    
    plt.xlabel(x_values)
    plt.ylabel(y_values)
    
    print(f"The r-squared is: {r**2}")
    
    plt.show()

# %%
city_data_labeled = city_data_df.rename(columns = {
    'Max Temp':'Max Temperature (°F)',
    'Lat':'Latitude',
    'Lng':'Longitude',
    'Humidity':'Humidity (%)',
    'Cloudiness':'Cloudiness (%)',
    'Wind Speed':'Wind Speed (m/s)'
})

# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_labeled[city_data_df['Lat'] >= 0]

# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_labeled[city_data_df['Lat'] < 0]

# %%
# Display sample data
northern_hemi_df.head()
# Out:
#                            City  Latitude  Longitude  Max Temperature (°F)  \
# City_ID
# 0        hawaiian paradise park   19.5933  -154.9731                 76.51
# 4                   egilsstadir   65.2653   -14.3948                 39.11
# 7                      hamilton   39.1834   -84.5333                 60.89
# 8                   barki saria   24.1667    85.8833                 93.31
# 10         vila franca do campo   37.7167   -25.4333                 64.81
#
#          Humidity (%)  Cloudiness (%)  Wind Speed (m/s) Country        Date
# City_ID
# 0                  79             100              8.05      US  1684288169
# 4                  70               0              5.75      IS  1684288170
# 7                  90               0              3.44      US  1684288171
# 8                  16              15              5.82      IN  1684288171
# 10                 93              83              5.79      PT  1684288172

# %%
# Display sample data
southern_hemi_df.head()
# Out:
#                       City  Latitude  Longitude  Max Temperature (°F)  \
# City_ID
# 1             port lincoln  -34.7333   135.8667                 57.24
# 2             puerto ayora   -0.7393   -90.3518                 78.55
# 3                 waitangi  -43.9535  -176.5597                 60.82
# 5             invercargill  -46.4000   168.3500                 47.44
# 6        port-aux-francais  -49.3500    70.2167                 44.80
#
#          Humidity (%)  Cloudiness (%)  Wind Speed (m/s) Country        Date
# City_ID
# 1                  58             100              7.58      AU  1684288169
# 2                  89              21              4.00      EC  1684288170
# 3                  83              94              5.99      NZ  1684288170
# 5                  89             100              8.81      NZ  1684288171
# 6                  91             100             22.28      TF  1684288171

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
f(northern_hemi_df,'Latitude','Max Temperature (°F)',10,20)
# Out:
# The r-squared is: 0.6580723667898902

# %%
# Linear regression on Southern Hemisphere
f(southern_hemi_df,'Latitude','Max Temperature (°F)',-30,40)
# Out:
# The r-squared is: 0.6242124360639841

# %% [markdown]
# **Discussion about the linear relationship:**
# As the magnitude of latitude increases, this represents cities that are further from the equator (further from latitude 0), and closer to the poles. As the magnitude of latitude increases, this association suggests that max temperatures increase as well. The r-squared value of this association is ~0.65, suggesting it is a moderately strong association.
#
# This makes sense because equator is the part of the earth that is 1) closest to the sun, 2) gets the most hours of sunlight, 3) gets the most direct sunlight. This access to direct sunlight is increases regional temperatures. The effect of this is mitigated by many other, smaller scale geographic conditions as well as global wind patterns. As such, this weakens the apparent association between temperature and latitude, leading to variance among max temperatures.
#
# Based on the scatterplot, it would seem that the association is stronger at lower latitueds (-60 to -30 degrees). However, we can also see that there are significantly fewer datapoints in that interval. This is due to the fact that our city latitudes were chosen uniformly randomly along the full range of latitudes (-90 to 90), but cities are *not* geographically distributed uniformly along the latitudes due to extreme environmental conditions as well as the geometric properties of spheres (the area enclosed by the top 1/4th of earth latitudes is approximately 1/7th of the total earth surface area).
#
# In order to control for this last factor, I would recommend we consider a stratified random sample of cities along latitude, selecting randomly uniformly from cities in different latitudes, so that the number of cities analyzed is comprable over comparable intervals of latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
f(northern_hemi_df,'Latitude','Humidity (%)',48,48)
# Out:
# The r-squared is: 6.52208857013829e-07

# %%
# Southern Hemisphere
f(southern_hemi_df,'Latitude','Humidity (%)',-21,41)
# Out:
# The r-squared is: 0.012250066316469271

# %% [markdown]
# **Discussion about the linear relationship:**
# As the magnitude of latitude increases, this association suggests that there is little to no impact on humidity. The r-squared value of this association is 0.002 in the northern hemisphere and ~0.07 in the southern hemisphere, suggesting it is a weak association.
#
# The scatter plot would suggest, however, that there is some 'clustering' around the equator (latitude = 0). This suggests that equatorial weather conditions could disproportionately lead to humid conditions.
#
# I would suggest considering a non-linear regression to better capture this association. Additionally, a stratified random sample of cities along latitude could enrich this analysis.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
f(northern_hemi_df,'Latitude','Cloudiness (%)',48,50)
# Out:
# The r-squared is: 0.006669225032242282

# %%
# Southern Hemisphere
f(southern_hemi_df,'Latitude','Cloudiness (%)',-55,38)
# Out:
# The r-squared is: 0.0005313916920968469

# %% [markdown]
# **Discussion about the linear relationship:**
# As the magnitude of latitude increases, this association suggests that there is little to no impact on cloudiness. The r-squared value of this association is 0.01 in the northern hemisphere and 0.002 in the southern hemisphere, suggesting it is a weak association.
#
# This is a great example of an association where linearity doesn't meaningfully capture interesting relationships between the two variables. Instead, it could be interesting to analyze the clusters. Consider the visible group close to 0% cloudiness, between -40 and -20 degrees latitude. I'd love to see these points plotted and identified on a map, to see if we can learn something about where in the world we see patterns of weather like these clusters.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
f(northern_hemi_df,'Latitude','Wind Speed (m/s)',5,25)
# Out:
# The r-squared is: 0.01786217457892028

# %%
# Southern Hemisphere
f(southern_hemi_df,'Latitude','Wind Speed (m/s)',-55,16)
# Out:
# The r-squared is: 0.04744014064896964

# %% [markdown]
# **Discussion about the linear relationship:**
# As the magnitude of latitude increases, this association suggests that there is little to no impact on windiness. The r-squared value of this association is 0.004 in the northern hemisphere and 0.08 in the southern hemisphere, suggesting it is a weak association.
#
# This association is very slightly negative, indicated by the negative slope of the linear regression. However, on the scatterplot we can see that there is a cluster of four points around -48 latitude, 30-35 windspeed that seem to be outliers. I would want to determine, quantitatively or qualitatively, if these are indeed outliers, or perhaps a randomly small subset of what could be a significant cluster of geographic locations with a unique weather pattern.
